# %%
import wave

# professor said there should be a number of channels but there is only one
with wave.open("/home/hamdi/CS482_HW3/test_anomaly/010001_ToyCar_case1_ab01_IND_ch1_0001.wav", "rb") as audio_file:
    num_channels = audio_file.getnchannels()
    num_samples_per_channel = audio_file.getnframes() // num_channels
    print("Num channels: ", num_channels, "Num samples: ", num_samples_per_channel)
# Out:
# Num channels:  1 Num samples:  176000

# %%
import tensorflow as tf

wavenet_model = tf.keras.Sequential()
wavenet_model.add(tf.keras.layers.Input(shape=[None, 5]))
for rate in (1, 2, 4, 8) * 2:
    wavenet_model.add(tf.keras.layers.Conv1D(
        filters=32, kernel_size=2, padding="causal", activation="relu",
        dilation_rate=rate))
wavenet_model.add(tf.keras.layers.Conv1D(filters=1, kernel_size=1, activation="sigmoid"))
input_layer = wavenet_model.get_layer(index=0)

# take the model example given in the book and change the 
input_layer.batch_input_shape = (None, None, num_channels * num_samples_per_channel)

# %%
import librosa
import os

audio_data, sampling_rate = librosa.load("/home/hamdi/CS482_HW3/normal_data/010003_ToyCar_case4_normal_IND_ch1_0003.wav")

def preprocess_audio(audio_data):
    # Resample the audio data to the required sampling rate
    audio_data = librosa.resample(audio_data, orig_sr=sampling_rate, target_sr=16000)

    # Normalize the audio data to have zero mean and unit variance
    audio_data = librosa.util.normalize(audio_data)

    # Convert the audio data to a 5-channel format
    num_samples = len(audio_data)
    num_channels = 5
    samples_per_channel = num_samples // num_channels
    audio_data = librosa.util.pad_center(audio_data, size=num_channels * samples_per_channel)
    audio_data = audio_data.reshape(-1, samples_per_channel, num_channels).transpose(0, 2, 1)

    return audio_data

def load_audio_data(data_dir):
    audio_data = []
    for filename in os.listdir(data_dir):
        if filename.endswith(".wav"):
            filepath = os.path.join(data_dir, filename)
            data, sr = librosa.load(filepath, sr=16000)
            audio_data.append(data)
    return audio_data

# %%
audio_data = load_audio_data("normal_data")
preprocessed_data = [preprocess_audio(data) for data in audio_data]

# %%
from sklearn.model_selection import train_test_split
import numpy as np

wavenet_model.compile(optimizer="adam", loss="binary_crossentropy")
X = np.all(preprocessed_data)
wavenet_model.fit(preprocessed_data, epochs=10)
# Out:
# Epoch 1/10
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /home/hamdi/CS482_HW3/test.ipynb Cell 5 line 6
#       <a href='vscode-notebook-cell://wsl%2Bubuntu/home/hamdi/CS482_HW3/test.ipynb#W4sdnNjb2RlLXJlbW90ZQ%3D%3D?line=3'>4</a> wavenet_model.compile(optimizer="adam", loss="binary_crossentropy")
#       <a href='vscode-notebook-cell://wsl%2Bubuntu/home/hamdi/CS482_HW3/test.ipynb#W4sdnNjb2RlLXJlbW90ZQ%3D%3D?line=4'>5</a> X = np.all(preprocessed_data)
# ----> <a href='vscode-notebook-cell://wsl%2Bubuntu/home/hamdi/CS482_HW3/test.ipynb#W4sdnNjb2RlLXJlbW90ZQ%3D%3D?line=5'>6</a> wavenet_model.fit(preprocessed_data, epochs=10)
#
# File ~/.venv/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
# ...
